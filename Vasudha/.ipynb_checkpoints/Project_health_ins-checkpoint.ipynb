# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
import os as csv

# Study data files
Insurance_path = "Health_insurance.csv"
County_results_path = "County_cases.csv"
# Read the data
Insurance_results = pd.read_csv(Insurance_path)
County_results = pd.read_csv(County_results_path)
Insurance_results.head()
# Out:
#    OBJECTID          GEO_ID        GEO_NAME GEO_PARENT_NAME  FIPS_CODE  \
# 0         1  0500000US01001  Autauga County         Alabama       1001
# 1         2  0500000US01003  Baldwin County         Alabama       1003
# 2         3  0500000US01005  Barbour County         Alabama       1005
# 3         4  0500000US01007     Bibb County         Alabama       1007
# 4         5  0500000US01009   Blount County         Alabama       1009
#
#    B27010_004E  B27010_004M  B27010_020E  B27010_020M  B27010_036E  ...  \
# 0         6247          723         6248          498        12131  ...
# 1        22820         1479        17847          982        45216  ...
# 2         1385          206         1598          264         3712  ...
# 3         2509          471         2247          433         4680  ...
# 4         7016          569         6396          483        12444  ...
#
#    DP03_0098E  DP03_0098M  DP03_0099E  DP03_0099M  DP03_0100E  DP03_0100M  \
# ...

# %%
County_results.head()
# Out:
#                last_update location_type    state county_name  \
# 0  2020-09-23 23:23:49 UTC        county  Alabama     Autauga
# 1  2020-09-23 23:23:49 UTC        county  Alabama     Baldwin
# 2  2020-09-23 23:23:49 UTC        county  Alabama     Barbour
# 3  2020-09-23 23:23:49 UTC        county  Alabama        Bibb
# 4  2020-09-23 23:23:49 UTC        county  Alabama      Blount
#
#        county_name_long  fips_code        lat        lon   NCHS_urbanization  \
# 0  Autauga, Alabama, US     1001.0  32.539527 -86.644082        Medium metro
# 1  Baldwin, Alabama, US     1003.0  30.727750 -87.722071         Small metro
# 2  Barbour, Alabama, US     1005.0  31.868263 -85.387129            Non-core
# 3     Bibb, Alabama, US     1007.0  32.996421 -87.125115  Large fringe metro
# 4   Blount, Alabama, US     1009.0  33.982109 -86.567906  Large fringe metro
#
#    total_population  confirmed  confirmed_per_100000  deaths  \
# 0           55200.0       1715               3106.88      25
# ...

# %%
Insurance_results
# Out:
#       OBJECTID          GEO_ID            GEO_NAME GEO_PARENT_NAME  FIPS_CODE  \
# 0            1  0500000US01001      Autauga County         Alabama       1001
# 1            2  0500000US01003      Baldwin County         Alabama       1003
# 2            3  0500000US01005      Barbour County         Alabama       1005
# 3            4  0500000US01007         Bibb County         Alabama       1007
# 4            5  0500000US01009       Blount County         Alabama       1009
# ...        ...             ...                 ...             ...        ...
# 3215      3216  0500000US72149  Villalba Municipio     Puerto Rico      72149
# 3216      3217  0500000US72151   Yabucoa Municipio     Puerto Rico      72151
# 3217      3218  0500000US72153     Yauco Municipio     Puerto Rico      72153
# 3218      3219  0500000US15005      Kalawao County          Hawaii      15005
# 3219      3220  0500000US48269         King County           Texas      48269
#
# ...

# %%
# Create a clean DataFrame by dropping all columns except 
Insurance_results[["GEO_NAME", "GEO_PARENT_NAME","DP03_0099PE","DP03_0099PM"]].head()
# Out:
#          GEO_NAME GEO_PARENT_NAME  DP03_0099PE  DP03_0099PM
# 0  Autauga County         Alabama          7.1          0.9
# 1  Baldwin County         Alabama         10.2          0.8
# 2  Barbour County         Alabama         11.2          1.6
# 3     Bibb County         Alabama          7.9          1.9
# 4   Blount County         Alabama         11.0          1.3

# %%
clean_Insurance_results_df=Insurance_results[["GEO_NAME", "GEO_PARENT_NAME","DP03_0099PE","DP03_0099PM"]]
clean_Insurance_results_df.head()
# Out:
#          GEO_NAME GEO_PARENT_NAME  DP03_0099PE  DP03_0099PM
# 0  Autauga County         Alabama          7.1          0.9
# 1  Baldwin County         Alabama         10.2          0.8
# 2  Barbour County         Alabama         11.2          1.6
# 3     Bibb County         Alabama          7.9          1.9
# 4   Blount County         Alabama         11.0          1.3

# %%
Insurance_df = clean_Insurance_results_df.rename(columns={"GEO_NAME":"GEO_NAME","GEO_PARENT_NAME":"GEO_PARENT_NAME",
                                                          "DP03_0099PE":"Percent of Population with No Health Insurance Coverage","DP03_0099PM":"Percent of Population with No Health Insurance Coverage *margin of error"})
Insurance_df.head()
# Out:
#          GEO_NAME GEO_PARENT_NAME  \
# 0  Autauga County         Alabama
# 1  Baldwin County         Alabama
# 2  Barbour County         Alabama
# 3     Bibb County         Alabama
# 4   Blount County         Alabama
#
#    Percent of Population with No Health Insurance Coverage  \
# 0                                                7.1
# 1                                               10.2
# 2                                               11.2
# 3                                                7.9
# 4                                               11.0
#
#    Percent of Population with No Health Insurance Coverage *margin of error
# 0                                                0.9
# 1                                                0.8
# 2                                                1.6
# 3                                                1.9
# 4                                                1.3

# %%
Insurance_df
# Out:
#                 GEO_NAME GEO_PARENT_NAME  \
# 0         Autauga County         Alabama
# 1         Baldwin County         Alabama
# 2         Barbour County         Alabama
# 3            Bibb County         Alabama
# 4          Blount County         Alabama
# ...                  ...             ...
# 3215  Villalba Municipio     Puerto Rico
# 3216   Yabucoa Municipio     Puerto Rico
# 3217     Yauco Municipio     Puerto Rico
# 3218      Kalawao County          Hawaii
# 3219         King County           Texas
#
#       Percent of Population with No Health Insurance Coverage  \
# 0                                                   7.1
# 1                                                  10.2
# 2                                                  11.2
# 3                                                   7.9
# 4                                                  11.0
# ...                                                 ...
# 3215                                                4.8
# ...

# %%
Insurance_df['county_name'] = Insurance_df['GEO_NAME'].str.split(' ', 1, expand=True)[0]
Insurance_df.head()
# Out:
#          GEO_NAME GEO_PARENT_NAME  \
# 0  Autauga County         Alabama
# 1  Baldwin County         Alabama
# 2  Barbour County         Alabama
# 3     Bibb County         Alabama
# 4   Blount County         Alabama
#
#    Percent of Population with No Health Insurance Coverage  \
# 0                                                7.1
# 1                                               10.2
# 2                                               11.2
# 3                                                7.9
# 4                                               11.0
#
#    Percent of Population with No Health Insurance Coverage *margin of error  \
# 0                                                0.9
# 1                                                0.8
# 2                                                1.6
# 3                                                1.9
# 4                                                1.3
#
#   county_name
# 0     Autauga
# 1     Baldwin
# 2     Barbour
# 3        Bibb
# ...

# %%
Insurance_df["county_name_long"] = Insurance_df["county_name"] + ", " + Insurance_df["GEO_PARENT_NAME"] + ", US"
Insurance_df.head()
# Out:
#          GEO_NAME GEO_PARENT_NAME  \
# 0  Autauga County         Alabama
# 1  Baldwin County         Alabama
# 2  Barbour County         Alabama
# 3     Bibb County         Alabama
# 4   Blount County         Alabama
#
#    Percent of Population with No Health Insurance Coverage  \
# 0                                                7.1
# 1                                               10.2
# 2                                               11.2
# 3                                                7.9
# 4                                               11.0
#
#    Percent of Population with No Health Insurance Coverage *margin of error  \
# 0                                                0.9
# 1                                                0.8
# 2                                                1.6
# 3                                                1.9
# 4                                                1.3
#
#   county_name      county_name_long
# 0     Autauga  Autauga, Alabama, US
# ...

# %%
# Combine the data into a single dataset
merged_data = pd.merge(County_results,Insurance_df,on="county_name_long")

# Display the data table for preview


merged_data.shape
# Out:
# (2971, 19)

# %%
# Display the data table for preview

merged_data.head()
# Out:
#                last_update location_type    state county_name_x  \
# 0  2020-09-23 23:23:49 UTC        county  Alabama       Autauga
# 1  2020-09-23 23:23:49 UTC        county  Alabama       Baldwin
# 2  2020-09-23 23:23:49 UTC        county  Alabama       Barbour
# 3  2020-09-23 23:23:49 UTC        county  Alabama          Bibb
# 4  2020-09-23 23:23:49 UTC        county  Alabama        Blount
#
#        county_name_long  fips_code        lat        lon   NCHS_urbanization  \
# 0  Autauga, Alabama, US     1001.0  32.539527 -86.644082        Medium metro
# 1  Baldwin, Alabama, US     1003.0  30.727750 -87.722071         Small metro
# 2  Barbour, Alabama, US     1005.0  31.868263 -85.387129            Non-core
# 3     Bibb, Alabama, US     1007.0  32.996421 -87.125115  Large fringe metro
# 4   Blount, Alabama, US     1009.0  33.982109 -86.567906  Large fringe metro
#
#    total_population  confirmed  confirmed_per_100000  deaths  \
# ...

# %%
print(merged_data['county_name_x'].value_counts())
print(merged_data['county_name_y'].value_counts())
# Out:
# Washington    30
# Jefferson     28
# Franklin      26
# Jackson       24
# Lincoln       24
#               ..
# Iosco          1
# Upton          1
# Massac         1
# Preston        1
# Loudon         1
# Name: county_name_x, Length: 1689, dtype: int64
# Washington    30
# Jefferson     28
# Franklin      26
# Jackson       24
# Lincoln       24
#               ..
# Iosco          1
# Upton          1
# Massac         1
# Preston        1
# Loudon         1
# Name: county_name_y, Length: 1689, dtype: int64

# %%
# Save clean merged data into a csv file
merged_data.to_csv("covidinsurance.csv", encoding='utf-8', index = False)

# %%
merged_data['county_name_long'].value_counts()
# Out:
# Jefferson, Mississippi, US    2
# Manassas, Virginia, US        2
# Roanoke, Virginia, US         2
# Jefferson, Louisiana, US      2
# Lake, Minnesota, US           2
#                              ..
# Mills, Iowa, US               1
# Madison, Virginia, US         1
# Louisa, Iowa, US              1
# Bell, Kentucky, US            1
# Johnson, Texas, US            1
# Name: county_name_long, Length: 2961, dtype: int64

# %%
Group1_df=merged_data[["state", "deaths_per_100000","Percent of Population with No Health Insurance Coverage"]]
Group1_df.head()
# Out:
#      state  deaths_per_100000  \
# 0  Alabama              45.29
# 1  Alabama              23.55
# 2  Alabama              27.15
# 3  Alabama              44.39
# 4  Alabama              26.02
#
#    Percent of Population with No Health Insurance Coverage
# 0                                                7.1
# 1                                               10.2
# 2                                               11.2
# 3                                                7.9
# 4                                               11.0

# %%
Grouped = Group1_df.groupby(["state"]).count()["deaths_per_100000"]
Grouped
# Out:
# state
# Alabama            66
# Alaska             15
# Arizona            13
# Arkansas           71
# California         44
# Colorado           55
# Connecticut         6
# Delaware            2
# Florida            62
# Georgia           157
# Hawaii              4
# Idaho              41
# Illinois           98
# Indiana            91
# Iowa               93
# Kansas            105
# Kentucky          120
# Louisiana          46
# Maine              16
# Maryland           20
# Massachusetts      12
# Michigan           78
# Minnesota          77
# Mississippi        81
# Missouri          107
# Montana            48
# Nebraska           89
# Nevada             15
# New Hampshire      10
# New Jersey         20
# New Mexico         26
# New York           60
# North Carolina     99
# North Dakota       51
# Ohio               87
# Oklahoma           75
# Oregon             35
# Pennsylvania       67
# Puerto Rico        50
# Rhode Island        5
# South Carolina     46
# ...

# %%
# Generate a bar plot showing the deaths_per_100000 for each state with the percentage Population with No Health Insurance Coverage using pandas. 
# Use DataFrame.plot() 
Group1_df.plot(kind="bar")
x_axis = np.arange(len("state"))
y_axis = np.arange(len(Grouped))
plt.ylim(0, max(y_axis)+30)
# Set a title for the chart
plt.title("COVID-19 Deaths and Percentage population with no Health Insurance in each state ")
plt.xlabel("State")
plt.ylabel("COVID-19 Deaths per 100000")
plt.tight_layout()
plt.show()

# %%
Alabama_df = Group1_df.loc[Group1_df["state"] == "Alabama",:]
Alabama_df
# Out:
#       state  deaths_per_100000  \
# 0   Alabama              45.29
# 1   Alabama              23.55
# 2   Alabama              27.15
# 3   Alabama              44.39
# 4   Alabama              26.02
# ..      ...                ...
# 61  Alabama              56.25
# 62  Alabama             128.70
# 63  Alabama              78.11
# 64  Alabama             101.77
# 65  Alabama              50.26
#
#     Percent of Population with No Health Insurance Coverage
# 0                                                 7.1
# 1                                                10.2
# 2                                                11.2
# 3                                                 7.9
# 4                                                11.0
# ..                                                ...
# 61                                                7.5
# 62                                               11.0
# 63                                                9.6
# ...

# %%
Group2_df=merged_data[["county_name_x","state", "deaths_per_100000","Percent of Population with No Health Insurance Coverage"]]
                       
Group2_df.head()
# Out:
#   county_name_x    state  deaths_per_100000  \
# 0       Autauga  Alabama              45.29
# 1       Baldwin  Alabama              23.55
# 2       Barbour  Alabama              27.15
# 3          Bibb  Alabama              44.39
# 4        Blount  Alabama              26.02
#
#    Percent of Population with No Health Insurance Coverage
# 0                                                7.1
# 1                                               10.2
# 2                                               11.2
# 3                                                7.9
# 4                                               11.0

# %%
County_Alabama_df = Group2_df.loc[Group2_df["state"] == "Alabama",:]
County_Alabama_df
# Out:
#    county_name_x    state  deaths_per_100000  \
# 0        Autauga  Alabama              45.29
# 1        Baldwin  Alabama              23.55
# 2        Barbour  Alabama              27.15
# 3           Bibb  Alabama              44.39
# 4         Blount  Alabama              26.02
# ..           ...      ...                ...
# 61    Tuscaloosa  Alabama              56.25
# 62        Walker  Alabama             128.70
# 63    Washington  Alabama              78.11
# 64        Wilcox  Alabama             101.77
# 65       Winston  Alabama              50.26
#
#     Percent of Population with No Health Insurance Coverage
# 0                                                 7.1
# 1                                                10.2
# 2                                                11.2
# 3                                                 7.9
# 4                                                11.0
# ..                                                ...
# ...

# %%
# Set x axis and tick locations
x_axis = np.arange(len(County_Alabama_df))
tick_locations = [value+0.4 for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(15,3))
plt.bar(x_axis,County_Alabama_df["deaths_per_100000"], color='r',alpha=0.5, align="edge")
plt.bar(x_axis,County_Alabama_df["Percent of Population with No Health Insurance Coverage"],color='b',alpha=0.5, align="edge")
plt.xticks(tick_locations,County_Alabama_df["county_name_x"], rotation="vertical")
# Set a title for the chart
plt.title("COVID-19 Deaths and Percentage population with no Health Insurance in Alabama ")
plt.xlabel("State")
plt.ylabel("COVID-19 Deaths per 100000")
plt.show()

# %%
County_NewYork_df = Group2_df.loc[Group2_df["state"] == "New York",:]
County_NewYork_df
# Out:
#      county_name_x     state  deaths_per_100000  \
# 1688        Albany  New York              43.59
# 1689      Allegany  New York               2.13
# 1690         Bronx  New York             343.77
# 1691        Broome  New York              35.49
# 1692   Cattaraugus  New York               7.72
# 1693        Cayuga  New York               2.57
# 1694    Chautauqua  New York               6.94
# 1695       Chemung  New York               3.50
# 1696      Chenango  New York              14.48
# 1697       Clinton  New York               6.19
# 1698      Columbia  New York              60.74
# 1699      Cortland  New York               0.00
# 1700      Delaware  New York               8.79
# 1701      Dutchess  New York              52.06
# 1702          Erie  New York              74.90
# 1703         Essex  New York               0.00
# 1704      Franklin  New York               0.00
# 1705        Fulton  New York              44.66
# ...

# %%
# Set x axis and tick locations
x_axis = np.arange(len(County_NewYork_df))
tick_locations = [value+0.4 for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(15,3))
plt.bar(x_axis,County_NewYork_df["deaths_per_100000"], color='r',alpha=0.5, align="edge")
plt.bar(x_axis,County_NewYork_df["Percent of Population with No Health Insurance Coverage"],color='g',alpha=0.5, align="edge")
plt.xticks(tick_locations,County_NewYork_df["county_name_x"], rotation="vertical")
# Set a title for the chart
plt.title("COVID-19 Deaths and Percentage population with no Health Insurance in New York ")
plt.xlabel("State")
plt.ylabel("COVID-19 Deaths per 100000")
plt.show()

# %%
Group3_df=merged_data[["county_name_x","state", "confirmed_per_100000","Percent of Population with No Health Insurance Coverage"]]
                       
Group3_df.head()
# Out:
#   county_name_x    state  confirmed_per_100000  \
# 0       Autauga  Alabama               3106.88
# 1       Baldwin  Alabama               2470.36
# 2       Barbour  Alabama               3300.75
# 3          Bibb  Alabama               2832.16
# 4        Blount  Alabama               2740.91
#
#    Percent of Population with No Health Insurance Coverage
# 0                                                7.1
# 1                                               10.2
# 2                                               11.2
# 3                                                7.9
# 4                                               11.0

# %%
County_Alabama_cases_df = Group3_df.loc[Group3_df["state"] == "Alabama",:]
County_Alabama_cases_df
# Out:
#    county_name_x    state  confirmed_per_100000  \
# 0        Autauga  Alabama               3106.88
# 1        Baldwin  Alabama               2470.36
# 2        Barbour  Alabama               3300.75
# 3           Bibb  Alabama               2832.16
# 4         Blount  Alabama               2740.91
# ..           ...      ...                   ...
# 61    Tuscaloosa  Alabama               3597.25
# 62        Walker  Alabama               3493.40
# 63    Washington  Alabama               3310.70
# 64        Wilcox  Alabama               4903.32
# 65       Winston  Alabama               3007.33
#
#     Percent of Population with No Health Insurance Coverage
# 0                                                 7.1
# 1                                                10.2
# 2                                                11.2
# 3                                                 7.9
# 4                                                11.0
# ...

# %%
# Set x axis and tick locations
x_axis = np.arange(len(County_Alabama_cases_df))
tick_locations = [value+0.4 for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(15,3))
plt.bar(x_axis,County_Alabama_cases_df["confirmed_per_100000"], color='r',alpha=0.5, align="edge")
plt.bar(x_axis,County_Alabama_cases_df["Percent of Population with No Health Insurance Coverage"],color='b',alpha=0.5, align="edge")
plt.xticks(tick_locations,County_Alabama_cases_df["county_name_x"], rotation="vertical")
# Set a title for the chart
plt.title("COVID-19 Confirmed cases and Percentage population with no Health Insurance in Alabama ")
plt.xlabel("State")
plt.ylabel("COVID-19 Confirmed cases per 100000")
plt.show()

# %%
County_NewYork_cases_df = Group3_df.loc[Group3_df["state"] == "New York",:]
County_NewYork_cases_df
# Out:
#      county_name_x     state  confirmed_per_100000  \
# 1688        Albany  New York                989.83
# 1689      Allegany  New York                210.53
# 1690         Bronx  New York               3665.83
# 1691        Broome  New York                761.31
# 1692   Cattaraugus  New York                332.11
# 1693        Cayuga  New York                261.98
# 1694    Chautauqua  New York                424.97
# 1695       Chemung  New York                421.04
# 1696      Chenango  New York                512.95
# 1697       Clinton  New York                193.08
# 1698      Columbia  New York                960.29
# 1699      Cortland  New York                340.79
# 1700      Delaware  New York                290.10
# 1701      Dutchess  New York               1731.58
# 1702          Erie  New York               1208.00
# 1703         Essex  New York                426.48
# 1704      Franklin  New York                128.23
# ...

# %%
# Set x axis and tick locations
x_axis = np.arange(len(County_NewYork_cases_df))
tick_locations = [value+0.4 for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(15,3))
plt.bar(x_axis,County_NewYork_cases_df["confirmed_per_100000"], color='r',alpha=0.5, align="edge")
plt.bar(x_axis,County_NewYork_cases_df["Percent of Population with No Health Insurance Coverage"],color='b',alpha=0.5, align="edge")
plt.xticks(tick_locations,County_NewYork_cases_df["county_name_x"], rotation="vertical")
# Set a title for the chart
plt.title("COVID-19 Confirmed cases and Percentage population with no Health Insurance in New York ")
plt.xlabel("State")
plt.ylabel("COVID-19 Confirmed cases per 100000")
plt.show()

# %%
# Set x axis and tick locations
x_axis = np.arange(len(County_Alabama_df))
tick_locations = [value+0.4 for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
fig= plt.figure(figsize=(15,3))
ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax.set_ylabel('COVID-19 Deaths_per_100000')
ax2.set_ylabel('Percent of Population with No Health Insurance Coverage')
plt.bar(x_axis,County_Alabama_df["deaths_per_100000"],ax=ax,color='r',alpha=0.5, align="edge")
plt.bar(x_axis,County_Alabama_df["Percent of Population with No Health Insurance Coverage"],ax=ax2,color='b',alpha=0.5, align="edge")
plt.xticks(tick_locations,County_Alabama_df["county_name_x"], rotation="vertical")
# Set x and y limits
plt.ylim(0, max(County_Alabama_df["deaths_per_100000"])+10)
plt.y_1lim(0, max(County_Alabama_df["Percent of Population with No Health Insurance Coverage"])+10)
# Set a title for the chart
plt.title("COVID-19 Deaths and Percentage population with no Health Insurance in Alabama ")
plt.xlabel("State")
plt.show()
# Out:
# -------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-29-6e8f8e2c6cb0> in <module>
#       8 ax.set_ylabel('COVID-19 Deaths_per_100000')
#       9 ax2.set_ylabel('Percent of Population with No Health Insurance Coverage')
# ---> 10 plt.bar(x_axis,County_Alabama_df["deaths_per_100000"],ax=ax,color='r',alpha=0.5, align="edge")
#      11 plt.bar(x_axis,County_Alabama_df["Percent of Population with No Health Insurance Coverage"],ax=ax2,color='b',alpha=0.5, align="edge")
#      12 plt.xticks(tick_locations,County_Alabama_df["county_name_x"], rotation="vertical")
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# -> 2441         **({"data": data} if data is not None else {}), **kwargs)
#    2442
#    2443
#
# ...

# %%
plt.scatter(merged_data['Percent of Population with No Health Insurance Coverage'], merged_data['deaths_per_100000'], color='steelblue', edgecolor='black')
plt.title("COVID-19 Deaths vs. Percentage of Population with No Health Insurance Coverage")
plt.xlabel("Percentage of Population with No Health Insurance Coverage")
plt.ylabel("Deaths per 100,000")
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(merged_data['Percent of Population with No Health Insurance Coverage'], 
                                                           merged_data['deaths_per_100000'])
regress_value = merged_data['Percent of Population with No Health Insurance Coverage'] * slope + intercept
plt.plot(merged_data['Percent of Population with No Health Insurance Coverage'], regress_value, 'r-')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(30,600),fontsize=15,color="red")
plt.grid()
print(f'The p-value is: {pvalue}')
print(f'The r-value is: {rvalue}')
# Out:
# The p-value is: nan
# The r-value is: nan

# %%
# Calculate correlation coefficient between percent population with no health insurance and deaths per 100000 people
merged_data.dropna
correlation = st.pearsonr(merged_data["Percent of Population with No Health Insurance Coverage"],merged_data["deaths_per_100000"])
correlation_coefficient = round(correlation[0], 2)

# Calculate linear regression model
x_values = merged_data["total_population"]
y_values = merged_data["confirmed_per_100000"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot total population against cases per 100000 people
# Annotate with linear regression equation
plt.scatter(merged_data["Percent of Population with No Health Insurance Coverage"], merged_data["deaths_per_100000"], marker="o", facecolors="steelblue", 
            edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (25,600), fontsize=14,color="red")
plt.grid()
plt.xlabel("Percentage of Population with No Health Insurance Coverage")
plt.ylabel("Deaths per 100,000")
plt.title("COVID-19 Deaths vs. Percentage of Population with No Health Insurance Coverage")
plt.show()
print(f"The r-value is {correlation_coefficient}")
# Out:
# -------------------------------------
# ValueErrorTraceback (most recent call last)
# <ipython-input-31-41e07d15c487> in <module>
#       1 # Calculate correlation coefficient between percent population with no health insurance and deaths per 100000 people
# ----> 2 correlation = st.pearsonr(merged_data["Percent of Population with No Health Insurance Coverage"],merged_data["deaths_per_100000"])
#       3 correlation_coefficient = round(correlation[0], 2)
#       4
#       5 # Calculate linear regression model
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3528     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3529     # [-5e210, 5e210, 3e200, -3e200]
# -> 3530     normxm = linalg.norm(xm)
#    3531     normym = linalg.norm(ym)
#    3532
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
# ...
