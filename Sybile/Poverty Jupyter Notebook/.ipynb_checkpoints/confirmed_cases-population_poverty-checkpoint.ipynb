# %%
import pandas as pd
import os as csv
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

path1 = '../Poverty Data/1_county_level_confirmed_cases.csv'
path2 = '../Poverty Data/Population_and_Poverty_-_Counties.csv'

csvfile1 = pd.read_csv(path1)
csvfile2 = pd.read_csv(path2)

confirmed_cases = pd.DataFrame(csvfile1)
population_poverty = pd.DataFrame(csvfile2)

# %%
confirmed_cases
# Out:
#                   last_update      location_type    state     county_name  \
# 0     2020-09-23 23:23:49 UTC             county  Alabama         Autauga
# 1     2020-09-23 23:23:49 UTC             county  Alabama         Baldwin
# 2     2020-09-23 23:23:49 UTC             county  Alabama         Barbour
# 3     2020-09-23 23:23:49 UTC             county  Alabama            Bibb
# 4     2020-09-23 23:23:49 UTC             county  Alabama          Blount
# ...                       ...                ...      ...             ...
# 3259  2020-09-23 23:23:49 UTC  special_exception     Utah    Central Utah
# 3260  2020-09-23 23:23:49 UTC  special_exception     Utah  Southeast Utah
# 3261  2020-09-23 23:23:49 UTC  special_exception     Utah  Southwest Utah
# 3262  2020-09-23 23:23:49 UTC  special_exception     Utah       TriCounty
# 3263  2020-09-23 23:23:49 UTC  special_exception     Utah    Weber-Morgan
#
#               county_name_long  fips_code        lat         lon  \
# 0         Autauga, Alabama, US     1001.0  32.539527  -86.644082
# 1         Baldwin, Alabama, US     1003.0  30.727750  -87.722071
# 2         Barbour, Alabama, US     1005.0  31.868263  -85.387129
# 3            Bibb, Alabama, US     1007.0  32.996421  -87.125115
# 4          Blount, Alabama, US     1009.0  33.982109  -86.567906
# ...                        ...        ...        ...         ...
# 3259    Central Utah, Utah, US        NaN  39.372319 -111.575868
# 3260  Southeast Utah, Utah, US        NaN  38.996171 -110.701396
# 3261  Southwest Utah, Utah, US        NaN  37.854472 -111.441876
# 3262       TriCounty, Utah, US        NaN  40.124915 -109.517442
# 3263    Weber-Morgan, Utah, US        NaN  41.271160 -111.914512
#
#        NCHS_urbanization  total_population  confirmed  confirmed_per_100000  \
# 0           Medium metro           55200.0       1715               3106.88
# 1            Small metro          208107.0       5141               2470.36
# 2               Non-core           25782.0        851               3300.75
# 3     Large fringe metro           22527.0        638               2832.16
# 4     Large fringe metro           57645.0       1580               2740.91
# ...                  ...               ...        ...                   ...
# 3259                 NaN               NaN        616                   NaN
# 3260                 NaN               NaN        186                   NaN
# 3261                 NaN               NaN       4067                   NaN
# 3262                 NaN               NaN        230                   NaN
# 3263                 NaN               NaN       4110                   NaN
#
#       deaths  deaths_per_100000
# 0         25              45.29
# 1         49              23.55
# 2          7              27.15
# 3         10              44.39
# 4         15              26.02
# ...      ...                ...
# 3259       3                NaN
# 3260       1                NaN
# 3261      30                NaN
# 3262       2                NaN
# 3263      30                NaN
#
# [3264 rows x 14 columns]

# %%
population_poverty
# Out:
#       OBJECTID          GEO_ID            GEO_NAME GEO_PARENT_NAME  \
# 0            1  0500000US01001      Autauga County         Alabama
# 1            2  0500000US01003      Baldwin County         Alabama
# 2            3  0500000US01005      Barbour County         Alabama
# 3            4  0500000US01007         Bibb County         Alabama
# 4            5  0500000US01009       Blount County         Alabama
# ...        ...             ...                 ...             ...
# 3215      3216  0500000US72149  Villalba Municipio     Puerto Rico
# 3216      3217  0500000US72151   Yabucoa Municipio     Puerto Rico
# 3217      3218  0500000US72153     Yauco Municipio     Puerto Rico
# 3218      3219  0500000US15005      Kalawao County          Hawaii
# 3219      3220  0500000US48269         King County           Texas
#
#       B17017_002E  B17017_002M  HOUSEBELOWPOVP_CALC  C17002_001E  C17002_001M  \
# 0          3175.0        367.0                15.04      54765.0        147.0
# 1          8656.0        605.0                11.01     204929.0        494.0
# 2          2383.0        259.0                25.94      22856.0        277.0
# 3           968.0        214.0                14.15      20468.0        201.0
# 4          2944.0        329.0                14.29      57082.0        150.0
# ...           ...          ...                  ...          ...          ...
# 3215       3735.0        281.0                48.43      22832.0         85.0
# 3216       6337.0        486.0                54.06      34052.0         92.0
# 3217       5819.0        336.0                53.93      36216.0         61.0
# 3218          4.0          3.0                 8.51         66.0         13.0
# 3219          2.0          5.0                 2.20        228.0         69.0
#
#       C17002_002E  ...  DP03_0131PE  DP03_0131PM  DP03_0135PE  DP03_0135PM  \
# 0          3364.0  ...         17.7          6.4          8.7          2.4
# 1          9186.0  ...         15.4          3.7          8.0          1.1
# 2          2914.0  ...         59.9          7.9         16.2          3.4
# 3          1207.0  ...         14.1         14.5          8.1          3.1
# 4          4173.0  ...         23.9          7.0         10.1          2.1
# ...           ...  ...          ...          ...          ...          ...
# 3215       5518.0  ...         71.5         12.5         43.3          6.2
# 3216       9838.0  ...         67.6          9.6         55.6          5.8
# 3217       9844.0  ...         59.6         10.6         48.2          4.1
# 3218          6.0  ...          NaN          NaN          0.0        100.0
# 3219         20.0  ...          0.0         79.8          0.0         57.3
#
#       DP02_0004E  DP02_0006E  DP02_0006M  DP02_0008E  DP02_0008M  DPO2_0004M
# 0        11988.0       768.0       217.0      2405.0       356.0       495.0
# 1        41452.0      2422.0       458.0      7485.0       684.0      1207.0
# 2         3908.0       346.0       107.0      1776.0       190.0       237.0
# 3         3626.0       387.0       144.0       934.0       237.0       370.0
# 4        11942.0      1185.0       254.0      1977.0       290.0       475.0
# ...          ...         ...         ...         ...         ...         ...
# 3215         NaN         NaN         NaN         NaN         NaN         NaN
# 3216         NaN         NaN         NaN         NaN         NaN         NaN
# 3217         NaN         NaN         NaN         NaN         NaN         NaN
# 3218         8.0         0.0        11.0         0.0        11.0         5.0
# 3219        42.0         0.0        13.0        11.0        10.0        16.0
#
# [3220 rows x 61 columns]

# %%
population_poverty['county_name'] = population_poverty['GEO_NAME'].str.split(' ', 1, expand=True)[0]
population_poverty
# Out:
#       OBJECTID          GEO_ID            GEO_NAME GEO_PARENT_NAME  \
# 0            1  0500000US01001      Autauga County         Alabama
# 1            2  0500000US01003      Baldwin County         Alabama
# 2            3  0500000US01005      Barbour County         Alabama
# 3            4  0500000US01007         Bibb County         Alabama
# 4            5  0500000US01009       Blount County         Alabama
# ...        ...             ...                 ...             ...
# 3215      3216  0500000US72149  Villalba Municipio     Puerto Rico
# 3216      3217  0500000US72151   Yabucoa Municipio     Puerto Rico
# 3217      3218  0500000US72153     Yauco Municipio     Puerto Rico
# 3218      3219  0500000US15005      Kalawao County          Hawaii
# 3219      3220  0500000US48269         King County           Texas
#
#       B17017_002E  B17017_002M  HOUSEBELOWPOVP_CALC  C17002_001E  C17002_001M  \
# 0          3175.0        367.0                15.04      54765.0        147.0
# 1          8656.0        605.0                11.01     204929.0        494.0
# 2          2383.0        259.0                25.94      22856.0        277.0
# 3           968.0        214.0                14.15      20468.0        201.0
# 4          2944.0        329.0                14.29      57082.0        150.0
# ...           ...          ...                  ...          ...          ...
# 3215       3735.0        281.0                48.43      22832.0         85.0
# 3216       6337.0        486.0                54.06      34052.0         92.0
# 3217       5819.0        336.0                53.93      36216.0         61.0
# 3218          4.0          3.0                 8.51         66.0         13.0
# 3219          2.0          5.0                 2.20        228.0         69.0
#
#       C17002_002E  ...  DP03_0131PM  DP03_0135PE  DP03_0135PM  DP02_0004E  \
# 0          3364.0  ...          6.4          8.7          2.4     11988.0
# 1          9186.0  ...          3.7          8.0          1.1     41452.0
# 2          2914.0  ...          7.9         16.2          3.4      3908.0
# 3          1207.0  ...         14.5          8.1          3.1      3626.0
# 4          4173.0  ...          7.0         10.1          2.1     11942.0
# ...           ...  ...          ...          ...          ...         ...
# 3215       5518.0  ...         12.5         43.3          6.2         NaN
# 3216       9838.0  ...          9.6         55.6          5.8         NaN
# 3217       9844.0  ...         10.6         48.2          4.1         NaN
# 3218          6.0  ...          NaN          0.0        100.0         8.0
# 3219         20.0  ...         79.8          0.0         57.3        42.0
#
#       DP02_0006E  DP02_0006M  DP02_0008E  DP02_0008M  DPO2_0004M  county_name
# 0          768.0       217.0      2405.0       356.0       495.0      Autauga
# 1         2422.0       458.0      7485.0       684.0      1207.0      Baldwin
# 2          346.0       107.0      1776.0       190.0       237.0      Barbour
# 3          387.0       144.0       934.0       237.0       370.0         Bibb
# 4         1185.0       254.0      1977.0       290.0       475.0       Blount
# ...          ...         ...         ...         ...         ...          ...
# 3215         NaN         NaN         NaN         NaN         NaN     Villalba
# 3216         NaN         NaN         NaN         NaN         NaN      Yabucoa
# 3217         NaN         NaN         NaN         NaN         NaN        Yauco
# 3218         0.0        11.0         0.0        11.0         5.0      Kalawao
# 3219         0.0        13.0        11.0        10.0        16.0         King
#
# [3220 rows x 62 columns]

# %%
population_poverty['country'] = 'US'
population_poverty
# Out:
#       OBJECTID          GEO_ID            GEO_NAME GEO_PARENT_NAME  \
# 0            1  0500000US01001      Autauga County         Alabama
# 1            2  0500000US01003      Baldwin County         Alabama
# 2            3  0500000US01005      Barbour County         Alabama
# 3            4  0500000US01007         Bibb County         Alabama
# 4            5  0500000US01009       Blount County         Alabama
# ...        ...             ...                 ...             ...
# 3215      3216  0500000US72149  Villalba Municipio     Puerto Rico
# 3216      3217  0500000US72151   Yabucoa Municipio     Puerto Rico
# 3217      3218  0500000US72153     Yauco Municipio     Puerto Rico
# 3218      3219  0500000US15005      Kalawao County          Hawaii
# 3219      3220  0500000US48269         King County           Texas
#
#       B17017_002E  B17017_002M  HOUSEBELOWPOVP_CALC  C17002_001E  C17002_001M  \
# 0          3175.0        367.0                15.04      54765.0        147.0
# 1          8656.0        605.0                11.01     204929.0        494.0
# 2          2383.0        259.0                25.94      22856.0        277.0
# 3           968.0        214.0                14.15      20468.0        201.0
# 4          2944.0        329.0                14.29      57082.0        150.0
# ...           ...          ...                  ...          ...          ...
# 3215       3735.0        281.0                48.43      22832.0         85.0
# 3216       6337.0        486.0                54.06      34052.0         92.0
# 3217       5819.0        336.0                53.93      36216.0         61.0
# 3218          4.0          3.0                 8.51         66.0         13.0
# 3219          2.0          5.0                 2.20        228.0         69.0
#
#       C17002_002E  ...  DP03_0135PE  DP03_0135PM  DP02_0004E  DP02_0006E  \
# 0          3364.0  ...          8.7          2.4     11988.0       768.0
# 1          9186.0  ...          8.0          1.1     41452.0      2422.0
# 2          2914.0  ...         16.2          3.4      3908.0       346.0
# 3          1207.0  ...          8.1          3.1      3626.0       387.0
# 4          4173.0  ...         10.1          2.1     11942.0      1185.0
# ...           ...  ...          ...          ...         ...         ...
# 3215       5518.0  ...         43.3          6.2         NaN         NaN
# 3216       9838.0  ...         55.6          5.8         NaN         NaN
# 3217       9844.0  ...         48.2          4.1         NaN         NaN
# 3218          6.0  ...          0.0        100.0         8.0         0.0
# 3219         20.0  ...          0.0         57.3        42.0         0.0
#
#       DP02_0006M  DP02_0008E  DP02_0008M  DPO2_0004M  county_name  country
# 0          217.0      2405.0       356.0       495.0      Autauga       US
# 1          458.0      7485.0       684.0      1207.0      Baldwin       US
# 2          107.0      1776.0       190.0       237.0      Barbour       US
# 3          144.0       934.0       237.0       370.0         Bibb       US
# 4          254.0      1977.0       290.0       475.0       Blount       US
# ...          ...         ...         ...         ...          ...      ...
# 3215         NaN         NaN         NaN         NaN     Villalba       US
# 3216         NaN         NaN         NaN         NaN      Yabucoa       US
# 3217         NaN         NaN         NaN         NaN        Yauco       US
# 3218        11.0         0.0        11.0         5.0      Kalawao       US
# 3219        13.0        11.0        10.0        16.0         King       US
#
# [3220 rows x 63 columns]

# %%
population_poverty['county_name_long'] = population_poverty['county_name'] + ', ' + population_poverty['GEO_PARENT_NAME'] + ', ' + population_poverty['country']
population_poverty
# Out:
#       OBJECTID          GEO_ID            GEO_NAME GEO_PARENT_NAME  \
# 0            1  0500000US01001      Autauga County         Alabama
# 1            2  0500000US01003      Baldwin County         Alabama
# 2            3  0500000US01005      Barbour County         Alabama
# 3            4  0500000US01007         Bibb County         Alabama
# 4            5  0500000US01009       Blount County         Alabama
# ...        ...             ...                 ...             ...
# 3215      3216  0500000US72149  Villalba Municipio     Puerto Rico
# 3216      3217  0500000US72151   Yabucoa Municipio     Puerto Rico
# 3217      3218  0500000US72153     Yauco Municipio     Puerto Rico
# 3218      3219  0500000US15005      Kalawao County          Hawaii
# 3219      3220  0500000US48269         King County           Texas
#
#       B17017_002E  B17017_002M  HOUSEBELOWPOVP_CALC  C17002_001E  C17002_001M  \
# 0          3175.0        367.0                15.04      54765.0        147.0
# 1          8656.0        605.0                11.01     204929.0        494.0
# 2          2383.0        259.0                25.94      22856.0        277.0
# 3           968.0        214.0                14.15      20468.0        201.0
# 4          2944.0        329.0                14.29      57082.0        150.0
# ...           ...          ...                  ...          ...          ...
# 3215       3735.0        281.0                48.43      22832.0         85.0
# 3216       6337.0        486.0                54.06      34052.0         92.0
# 3217       5819.0        336.0                53.93      36216.0         61.0
# 3218          4.0          3.0                 8.51         66.0         13.0
# 3219          2.0          5.0                 2.20        228.0         69.0
#
#       C17002_002E  ...  DP03_0135PM  DP02_0004E  DP02_0006E  DP02_0006M  \
# 0          3364.0  ...          2.4     11988.0       768.0       217.0
# 1          9186.0  ...          1.1     41452.0      2422.0       458.0
# 2          2914.0  ...          3.4      3908.0       346.0       107.0
# 3          1207.0  ...          3.1      3626.0       387.0       144.0
# 4          4173.0  ...          2.1     11942.0      1185.0       254.0
# ...           ...  ...          ...         ...         ...         ...
# 3215       5518.0  ...          6.2         NaN         NaN         NaN
# 3216       9838.0  ...          5.8         NaN         NaN         NaN
# 3217       9844.0  ...          4.1         NaN         NaN         NaN
# 3218          6.0  ...        100.0         8.0         0.0        11.0
# 3219         20.0  ...         57.3        42.0         0.0        13.0
#
#       DP02_0008E  DP02_0008M  DPO2_0004M  county_name  country  \
# 0         2405.0       356.0       495.0      Autauga       US
# 1         7485.0       684.0      1207.0      Baldwin       US
# 2         1776.0       190.0       237.0      Barbour       US
# 3          934.0       237.0       370.0         Bibb       US
# 4         1977.0       290.0       475.0       Blount       US
# ...          ...         ...         ...          ...      ...
# 3215         NaN         NaN         NaN     Villalba       US
# 3216         NaN         NaN         NaN      Yabucoa       US
# 3217         NaN         NaN         NaN        Yauco       US
# 3218         0.0        11.0         5.0      Kalawao       US
# 3219        11.0        10.0        16.0         King       US
#
#                county_name_long
# 0          Autauga, Alabama, US
# 1          Baldwin, Alabama, US
# 2          Barbour, Alabama, US
# 3             Bibb, Alabama, US
# 4           Blount, Alabama, US
# ...                         ...
# 3215  Villalba, Puerto Rico, US
# 3216   Yabucoa, Puerto Rico, US
# 3217     Yauco, Puerto Rico, US
# 3218        Kalawao, Hawaii, US
# 3219            King, Texas, US
#
# [3220 rows x 64 columns]

# %%
population_poverty = population_poverty.loc[:, ['county_name_long', 'HOUSEBELOWPOVP_CALC']]
population_poverty
# Out:
#                county_name_long  HOUSEBELOWPOVP_CALC
# 0          Autauga, Alabama, US                15.04
# 1          Baldwin, Alabama, US                11.01
# 2          Barbour, Alabama, US                25.94
# 3             Bibb, Alabama, US                14.15
# 4           Blount, Alabama, US                14.29
# ...                         ...                  ...
# 3215  Villalba, Puerto Rico, US                48.43
# 3216   Yabucoa, Puerto Rico, US                54.06
# 3217     Yauco, Puerto Rico, US                53.93
# 3218        Kalawao, Hawaii, US                 8.51
# 3219            King, Texas, US                 2.20
#
# [3220 rows x 2 columns]

# %%
merged_data = pd.merge(confirmed_cases, population_poverty, on='county_name_long', how='inner')
merged_data.head()
# Out:
#                last_update location_type    state county_name  \
# 0  2020-09-23 23:23:49 UTC        county  Alabama     Autauga
# 1  2020-09-23 23:23:49 UTC        county  Alabama     Baldwin
# 2  2020-09-23 23:23:49 UTC        county  Alabama     Barbour
# 3  2020-09-23 23:23:49 UTC        county  Alabama        Bibb
# 4  2020-09-23 23:23:49 UTC        county  Alabama      Blount
#
#        county_name_long  fips_code        lat        lon   NCHS_urbanization  \
# 0  Autauga, Alabama, US     1001.0  32.539527 -86.644082        Medium metro
# 1  Baldwin, Alabama, US     1003.0  30.727750 -87.722071         Small metro
# 2  Barbour, Alabama, US     1005.0  31.868263 -85.387129            Non-core
# 3     Bibb, Alabama, US     1007.0  32.996421 -87.125115  Large fringe metro
# 4   Blount, Alabama, US     1009.0  33.982109 -86.567906  Large fringe metro
#
#    total_population  confirmed  confirmed_per_100000  deaths  \
# 0           55200.0       1715               3106.88      25
# 1          208107.0       5141               2470.36      49
# 2           25782.0        851               3300.75       7
# 3           22527.0        638               2832.16      10
# 4           57645.0       1580               2740.91      15
#
#    deaths_per_100000  HOUSEBELOWPOVP_CALC
# 0              45.29                15.04
# 1              23.55                11.01
# 2              27.15                25.94
# 3              44.39                14.15
# 4              26.02                14.29

# %%
merged_data.to_csv('../Poverty Data/confirmed_cases-population_poverty.csv', index=False)

# %%
plt.scatter(merged_data['HOUSEBELOWPOVP_CALC'], merged_data['confirmed_per_100000'], color='green', edgecolor='black')
plt.title("Confirmed Cases vs. Percentage of Household Below Income Level")
plt.xlabel("Household Below Income Level")
plt.ylabel("Confirmed cases per 100,000")
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(merged_data['HOUSEBELOWPOVP_CALC'], 
                                                           merged_data['confirmed_per_100000'])
regress_value = merged_data['HOUSEBELOWPOVP_CALC'] * slope + intercept
plt.plot(merged_data['HOUSEBELOWPOVP_CALC'], regress_value, 'r-')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(30, 10000),fontsize=15,color="red")
plt.grid()
print(f'The p-value is: {pvalue}')
print(f'The r-value is: {rvalue}')
plt.savefig(Death Rate vs. Total Population)
# Out:
# The p-value is: 1.1721639923375325e-33
# The r-value is: 0.21922184609942164

# %%
plt.scatter(merged_data['HOUSEBELOWPOVP_CALC'], merged_data['deaths_per_100000'], color='green', edgecolor='black')
plt.title("Death Rate vs. Percentage of Household Below Income Level")
plt.xlabel("Household Below Income Level")
plt.ylabel("Death Rate per 100,000")
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(merged_data['HOUSEBELOWPOVP_CALC'], 
                                                           merged_data['deaths_per_100000'])
regress_value = merged_data['HOUSEBELOWPOVP_CALC'] * slope + intercept
plt.plot(merged_data['HOUSEBELOWPOVP_CALC'], regress_value, 'r-')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(30, 600),fontsize=15,color="red")
plt.grid()
print(f'The p-value is: {pvalue}')
print(f'The r-value is: {rvalue}')
# Out:
# The p-value is: 4.17425311193131e-28
# The r-value is: 0.19971242720508164

# %%
plt.scatter(merged_data['total_population'], merged_data['confirmed_per_100000'], color='green', edgecolor='black')
plt.title("Confirmed Cases vs. Total Population")
plt.xlabel("Total Population")
plt.ylabel("Confirmed cases per 100,000")
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(merged_data['total_population'], 
                                                           merged_data['confirmed_per_100000'])
regress_value = merged_data['total_population'] * slope + intercept
plt.plot(merged_data['total_population'], regress_value, 'r-')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(30, 10000),fontsize=15,color="red")
plt.grid()
print(f'The p-value is: {pvalue}')
print(f'The r-value is: {rvalue}')
# Out:
# The p-value is: 2.427864511789265e-05
# The r-value is: 0.07736362490751379

# %%
plt.scatter(merged_data['total_population'], merged_data['deaths_per_100000'], color='green', edgecolor='black')
plt.title("Death Rate vs. Total Population")
plt.xlabel("Total Population")
plt.ylabel("Death Rate per 100,000")
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(merged_data['total_population'], 
                                                           merged_data['deaths_per_100000'])
regress_value = merged_data['total_population'] * slope + intercept
plt.plot(merged_data['total_population'], regress_value, 'r-')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(30, 600),fontsize=15,color="red")
plt.grid()
print(f'The p-value is: {pvalue}')
print(f'The r-value is: {rvalue}')
plt.savefig(Death Rate vs. Total Population)
# Out:
# The p-value is: 1.1322107590840074e-15
# The r-value is: 0.14625393113721283
